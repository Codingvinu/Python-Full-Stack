# %%
"""Logical Operator
these are 3 keywords 
1. Logical AND(binary Operator)
2. Logical OR (binary Operator)
3. Logical NOT(unary operator)

Working of AND: AND results in True only if the two operands are True , in the remaining cases it will result in false

Truth table for AND: 
operand -1        Operand-2           Result
True               True                True
False              True                False
True               False               False
False              False               False

Working of OR: Or results in true if atleast one of the two boolean operands is true, else it will be false
True               True                True
False              True                True
True               False               True
False              False               False

Working of NOT: It is an unary operator that works on single boolean operand it gives the inverse of the boolean operand
True               True                True
False              True                False
True               False               False
False              False               True 

"""
#write a program to check if the given input number exits or not
"""a=int(input("enter any number:"))
if (0<=a<=100):
    print("number exits in the range of 0 to 100")
else:
    print("number not exits in the range of 0 to 100")"""
#or
a=int(input("enter any number:"))
b=(a>0 or a<100)
print(b)

a=10
b=20
print(a>5 and b<30)
print(a>20 or b==20)
print(not(a==10))
# Out:
# enter any number: 20
# True
# True
# True
# False

# %%
"""
#member ship operator

they are used to check if an object is existing in a group of objects
they are keywords -in , not in 
they always returns boolean results only"""
a=[20,30,40,50]
print(30 in a)
print(35 not in a)
# Out:
# True
# True

# %%
""" 
Identity Operators
they are used to check if two objects are the same in memory 
these are keywords-is, is not
they always return boolean result only
same immutable objects present with two variables poiny to same memory
same mutable objects present with two variables point to different memory"""
#id check print(id(a)) check the address
a = 56
b = 56
print(a is b)

a= [1,5,7]
b= [5,6,7]
print (a is not b)
# Out:
# True
# True

# %%
""" Assignment Operator
They are used to assign values to variables or update values present in variable

=   - is used to assign value to variable
+=  - used for adding certain quantity to exitsting values and reassign to the same variable
-=  -
*=  -
/=  -
//= -
**= -
%=  -
"""
a=2
b=a+5
print(b)

#or
n=2
n+=5
print(n)
n-=10
print(n)

#or
z=5
z*=5
print(z)

z=5
z/=5
print(z)

z=5
z//=5
print(z)

z=5
z**=5
print(z)
# Out:
# 7
# 7
# -3
# 25
# 1.0
# 1
# 3125
