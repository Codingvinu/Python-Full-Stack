# %%
"""
String
string is an immutable , ordered sequence of charecters enclosed in quotation marks
for single line string we use one quotation mark
for mutliple line string we use three quotation marks
only quotation marks without any charecters represent empty string"""
string = "vinod123. []"
print(string)
print(type(string))
# Out:
# vinod123. []
# <class 'str'>

# %%
"""
String input:
to take any string input from the user, we use input() function"""
s=input()
print(type(s))
print(s)
# Out:
#  [1,4,5,7]
# <class 'str'>
# [1,4,5,7]

# %%
"""Type Casting to string:
to convert any other compatible data type into stringdata type we use str() function"""
a=15
b=str(a)
print(b)
print(type(b))
# Out:
# 15
# <class 'str'>

# %%
""" String Operations:
1. operators that work on strings
a. + - this can be used for joining two or more strings together"""
a="vinod"
b="sai"
c=(a+" "+b)
print(c)
# Out:
# vinod sai

# %%
"""String repetation - * - represents charecters present in given string"""
a="vinod"
print(a*3)
# Out:
# vinodvinodvinod

# %%
""" Relational Operators
Compares based on ascii values
we can use identity operator and membership operators"""
a=20
b=30
print('a'>'b')

print('p' in 'vinod')
print('p' in 'python')
print('p' in 'Python')
# Out:
# False
# False
# True
# False

# %%
""" Indexing and slicing 
Index tells about position of charecters 
we have two type of indexing 
1.zero based indexing it goes from left to right. it runs from 0 to n-1 where represents total no of charecters

2.nagative indexing
it goes from  right to left
it runs from -1 to -n
"""
a="python"
print(a[2])

b="python"
print(a[-3])
# Out:
# t
# h

# %%
"""write a program to check if the last but one charecter from the given input string is a vowel True of false is the expected output"""
a=input("enter any string: ")
b=a[-2]
print(b in 'aeiouAEIOU')
# Out:
# enter any string:  SAI
# True

# %%
"""Slicing
obtaining a substring from given string is called as slicing 
string [start : stop+1 : step]"""
a='python'
print(a[1:5])
print(a[1:5:2])
print(a[::2])
print(a[-1:-5])
# Out:
# ytho
# yh
# pto
