# %%
#Operators
""" operators are special symbols (or) keywords used to perfrom operations on operands

In python these are the different types operators

1) Arthematic operator
2) Relational operator
3) Logical Operator
4) Membership operator
5) Identity operator
6) Assignment operator
7) Bitwise operator

1. Arthematic operator
These are special symbols 

+ - Addition
- - Substraction
* - Multiplication
/ - Division
% - Modulus
** - Exponent
// - Floor division"""

a=int(input("enter the first number:"))
b=int(input("enter the second number:"))
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)
print(a//b)
# Out:
# enter the first number: 20
# enter the second number: 10
# 30
# 10
# 200
# 2.0
# 0
# 10240000000000
# 2

# %%
# Different types to write code.
a=20
b=30
print(a+b)

#OR 
c=20
d=30
e=c+d
print(e)

#OR

f=input()
g=input()
h=f+g
print(h)
print(type(f))
# Out:
# 50
# 50
#  20
#  30
# 2030
# <class 'str'>

# %%
# 2. Relational operator (or) Comparision Operator
""" these are the special symbols they always returns boolean values only based on the comparision made 
> - Grater than
< - Less than
>= - Grater than or equal to
<= - Less than or equal to
== - Equal to
!= - Not equal """

a= int(input("enter first number:"))
b= int(input("enter Second Number:"))
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)
# Out:
# enter first number: 10
# enter Second Number: 20
# False
# True
# False
# True
# False
# True

# %%
# Task - two lines of input are given check weather the second number is a square root of first number code in python
a = float(input("Enter the first number: "))
b = float(input("Enter the second number: "))
if b * b == a:
    print("Yes, the second number is the square root of the first number.")
else:
    print("No, the second number is not the square root of the first number.")
# Out:
# Enter the first number:  4
# Enter the second number:  2
# Yes, the second number is the square root of the first number.
